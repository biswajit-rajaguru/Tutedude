# %%
print(bool(""))
# Out:
# False

# %%
print(type("1+1"))
# Out:
# <class 'str'>

# %%
# main.py

import tkinter as tk
from CalculatorUI import CalculatorUI
from CalculatorLogic import CalculatorLogic


def Calculator():
    root = tk.Tk()
    root.geometry("700x500")
    root.title("Calculator")

    logic = CalculatorLogic()

    def handle_key(key):
        key_map = {"×": "*", "÷": "/"}
        value = logic.process_input(key_map.get(key, key))
        ui.set_display(value)

    ui = CalculatorUI(root, on_key=handle_key)
    root.mainloop()


if __name__ == "__main__":
    Calculator()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 25
#      21     root.mainloop()
#      24 if __name__ == "__main__":
# ---> 25     main()
#
# Cell In[1], line 20, in main()
#      17     value = logic.process_input(key_map.get(key, key))
#      18     ui.set_display(value)
# ---> 20 ui = CalculatorUI(root, on_key=handle_key)
#      21 root.mainloop()
#
# File ~/git_repos/Courses/Tutedude/Python/Notes/CalculatorUI.py:45, in CalculatorUI.__init__(self, master, on_key)
#      38 self.displayFont = tkfont.Font(root=self.winfo_toplevel(), family="Helvetica", size=24)
#      39 self._button_font = tkfont.Font(
#      40         root= master,
#      41         family="Helvetica",
#      42         size=14,
#      43         weight="bold"
#      44     )
# ---> 45 self._build_ui()
#      46 self._bind_resize()
#
# ...

# %%
import tkinter as tk
from CalculatorWidget import Calculator

root = tk.Tk()
root.geometry("700x500")
root.title("Calculator")
root.rowconfigure(0, weight = 1)
root.columnconfigure(0, weight = 1)
root.rowconfigure(1, weight = 1)
root.columnconfigure(1, weight = 1)

for i in range(2):
    for j in range(2):
        Calculator(root).grid(row = i, column = j, sticky = "nsew")

root.mainloop()

# %%
import tkinter as tk
from CalculatorWidget import Calculator

root = tk.Tk()
root.geometry("700x500")
root.title("Calculator")
# root.rowconfigure(0, weight = 1)
# root.columnconfigure(0, weight = 1)
# root.rowconfigure(1, weight = 1)
# root.columnconfigure(1, weight = 1)

Calculator(root).pack(expand = True, fill = "both")
Calculator(root).pack(expand = True, fill = "both")
Calculator(root).pack(expand = True, fill = "both")
Calculator(root).pack(expand = True, fill = "both")
root.mainloop()
