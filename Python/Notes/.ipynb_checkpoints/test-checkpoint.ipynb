# %%
try:
    with open("some", "rt") as f:
        print(f.read())
except FileNotFoundError as error:
    print(f'Error: The file "sample.txt" was not found.')
    print(error)
except "Exception":
    print("Some error happened")
else:
    pass
# Out:
# Error: The file "sample.txt" was not found.
# [Errno 2] No such file or directory: 'some'

# %%
def create_marks_dictionary():
    marks_dictionary = {}
    while True:
        print()
        text1 = "Creating marks list"
        print(f"{text1}\n{'='*len(text1)}\n")
        print("Enter student name and marks to add to the list or 'done' when there is no further input\n")
        name = input("Name: ")
        if name == 'done':
            break
        if name in marks_dictionary.keys():
            x = inputprint("{name}'s marks are already in the list, '")
        try:
            marks = float(input("Marks: "))
        except ValueError:
            print("Marks should be an integer")
            continue
        else:
            marks_dictionary[name] = marks
        
        marks_dictionary[name] = marks
    return marks_dictionary

marks_dictionary = create_marks_dictionary()

for key in marks_dictionary:
    print(f"{key}: {marks_dictionary[key]}")
# Out:
# Creating marks list
# ===================
#
# Enter student name and marks to add to the list or 'done' when there is no further input
# Name:  A
# Marks:  1
# Creating marks list
# ===================
#
# Enter student name and marks to add to the list or 'done' when there is no further input
# Name:  b
# Marks:  1
# Creating marks list
# ===================
#
# Enter student name and marks to add to the list or 'done' when there is no further input
# Name:  c
# Marks:  7
# Creating marks list
# ===================
#
# Enter student name and marks to add to the list or 'done' when there is no further input
# Name:  dh
# Marks:  h
# Marks should be an integer
#
# Creating marks list
# ===================
#
# Enter student name and marks to add to the list or 'done' when there is no further input
# Name:  done
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 24
#      20     return marks_dictionary
#      22 marks_dictionary = create_marks_dictionary()
# ---> 24 for key in marks-dictionary:
#      25     print(f"{key}: {marks_dictionary[key]}")
#
# NameError: name 'marks' is not defined
