# %%
strings = ["aaa", "bbb", "z","zz", "aba", "111"]
sort_key_generator = lambda s: (len(s),s)
sorted_strings = sorted(strings, key = sort_key_generator)
print(strings)
print(sorted_strings)
# Out:
# ['aaa', 'bbb', 'z', 'zz', 'aba', '111']
# ['z', 'zz', '111', 'aaa', 'aba', 'bbb']
